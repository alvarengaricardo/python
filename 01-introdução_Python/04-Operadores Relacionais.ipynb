# %% [markdown]
# # Operadores Relacionais

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 5
b = 5
c = 7

# %%
a == b
# Out:
# True

# %%
a == c
# Out:
# False

# %%
a != b
# Out:
# False

# %%
a != c
# Out:
# True

# %%
a > b
# Out:
# False

# %%
a > c
# Out:
# False

# %%
c > a
# Out:
# True

# %%
a < b
# Out:
# False

# %%
a < c
# Out:
# True

# %%
a >= b
# Out:
# True

# %%
a >= c
# Out:
# False

# %%
a <= b
# Out:
# True

# %%
a <= c
# Out:
# True

# %%
b != a + 1
# Out:
# True

# %%
a * 2 >= b
# Out:
# True

# %%
x = y = z = False

# %%
n1 = n2 = 0

# %%
n1 = int(input("n1: "))
# Out:
# n1: 3

# %%
n2 = int(input("n2: "))
# Out:
# n2: 3

# %%
x = n1 == n2 # x é o resultado da comparação de n1 e n2
x
# Out:
# True

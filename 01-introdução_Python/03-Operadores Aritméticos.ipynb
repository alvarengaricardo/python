# %% [markdown]
# # Operadores Aritméticos

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = 10
b = 5
c = 11

# %%
a + b
# Out:
# 15

# %%
a - b
# Out:
# 5

# %%
b - a
# Out:
# -5

# %%
a * b
# Out:
# 50

# %%
a / b
# Out:
# 2.0

# %%
b / a
# Out:
# 0.5

# %%
a // b # parte inteira da divisão de a por b
# Out:
# 2

# %%
b // a
# Out:
# 0

# %%
a % b # resto de a divido por b
# Out:
# 0

# %%
b % a
# Out:
# 5

# %%
a ** b
# Out:
# 100000

# %%
b ** a
# Out:
# 9765625

# %% [markdown]
# ##### Ordem de Precedência de Operadores

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a + b * c
# Out:
# 65

# %%
(a + b) * c
# Out:
# 165

# %%
x = y = z = 0

# %%
x = 7
y = 9

# %%
z = x + y
z
# Out:
# 16

# %%
x = int(input('Valor de x: '))
# Out:
# Valor de x: 3

# %%
y = int(input('Valor de y: '))
# Out:
# Valor de y: 4

# %%
z = x + y
z
# Out:
# 7
